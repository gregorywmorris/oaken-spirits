# %% [markdown]
# Test shipping

# %%
import sys
import os
import json
import logging
from kafka import KafkaConsumer, KafkaProducer
from json import loads
import random
import datetime
import mysql.connector
import boto3
from logging.handlers import RotatingFileHandler

# %%
def accounting_consumer():
    # Configure logging
    logger = logging.getLogger(__name__)
    logger.setLevel(logging.ERROR)

    mysql_conn = mysql.connector.connect(
        host='localhost',
        user='mysql',
        password='mysql',
        database='oaken'
    )

    mysql_cursor = mysql_conn.cursor()

    # Kafka consumers
    shipping_consumer = KafkaConsumer(
        'shipping',
        bootstrap_servers=['localhost:9092'],
        auto_offset_reset='earliest',  # Start consuming from the earliest offset
        enable_auto_commit=True,       # Automatically commit offsets
        group_id='oaken_accounting_group',  # Specify a consumer group
        value_deserializer=lambda x: loads(x.decode('utf-8')))

    shipping_consumer.subscribe(topics='shipping')

    for shipping_message in shipping_consumer:
        try:
            shipping_data = shipping_message.value

            invoice = shipping_data.get('Invoice', '')

            shipping_expense = float(shipping_data.get('ShippingCost')) * -1

            sales = float(shipping_data.get('SaleDollars'))

            # MySQL
            try:
                LEDGER_CREDIT = """
                    INSERT INTO salesLedger (Invoice, Credit, Note)
                    VALUES (%s, %s, 'Sale')
                """
                credit_data = (invoice, sales)
                mysql_cursor.execute(LEDGER_CREDIT, credit_data)
                mysql_conn.commit()
            except Exception as e:
                logger.error(f"Error processing message: {e}")
                pass

            try:
                LEDGER_DEBIT = """
                    INSERT INTO salesLedger (Invoice, Debit, Note)
                    VALUES (%s, %s, 'Shipping')
                """
                debit_data = (invoice, shipping_expense)
                mysql_cursor.execute(LEDGER_DEBIT, debit_data)
                mysql_conn.commit()
            except Exception as e:
                logger.error(f"Error processing message: {e}")
                pass

        except Exception as e:
            logger.error(f"Error processing message: {e}")
            pass

    mysql_cursor.close()
    mysql_conn.close()

# %%
accounting_consumer()
# Out:
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# ...
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# Error processing message: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`oaken`.`salesLedger`, CONSTRAINT `salesLedger_ibfk_1` FOREIGN KEY (`Invoice`) REFERENCES `sales` (`Invoice`))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 accounting_consumer()
#
# Cell In[2], line 26, in accounting_consumer()
#      16 shipping_consumer = KafkaConsumer(
#      17     'shipping',
#      18     bootstrap_servers=['localhost:9092'],
#    (...)
#      21     group_id='oaken_accounting_group',  # Specify a consumer group
#      22     value_deserializer=lambda x: loads(x.decode('utf-8')))
#      24 shipping_consumer.subscribe(topics='shipping')
# ---> 26 for shipping_message in shipping_consumer:
#      27     try:
#      28         shipping_data = shipping_message.value
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/miniconda3/envs/kafka/lib/python3.11/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
# sample output
'''
{'Invoice/Item Number': 'S29198800001', 'Date': '11/20/2015', 'Store Number': '2191', 'Store Name': 'Keokuk Spirits', 
'Address': '1013 MAIN', 'City': 'KEOKUK', 'Zip Code': '52632', 'Store Location': '1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)', 
'County Number': '56', 'County': 'Lee', 'Category': '', 'Category Name': '', 'Vendor Number': '255', 'Vendor Name': 'Wilson Daniels Ltd.', 
'Item Number': '297', 'Item Description': 'Templeton Rye w/Flask', 'Pack': '6', 'Bottle Volume (ml)': '750', 'State Bottle Cost': '$18.09', 
'State Bottle Retail': '$27.14', 'Bottles Sold': '6', 'Sale (Dollars)': '$162.84', 'Volume Sold (Liters)': '4.50', 'Volume Sold (Gallons)': '1.19'}
'''
