# %% [markdown]
# Test MySQL

# %%
import sys
import os
import json
import logging
from kafka import KafkaConsumer, KafkaProducer
from json import loads
import random
import datetime
import mysql.connector
import boto3
from logging.handlers import RotatingFileHandler

# %%
def mysql_consumer():
    mysql_conn = mysql.connector.connect(
        host='localhost',
        user='mysql',
        password='mysql',
        database='oaken'
    )
    mysql_cursor = mysql_conn.cursor()

    # Create a consumer instance
    consumer = KafkaConsumer(
        'mysql',
        bootstrap_servers=['localhost:9092'],
        auto_offset_reset='earliest',  # Start consuming from the earliest offset
        enable_auto_commit=True,       # Automatically commit offsets
        group_id='my_consumer_group',  # Specify a consumer group
        value_deserializer=lambda x: loads(x.decode('utf-8')))

    consumer.subscribe(topics=['mysql'])

    invoice_producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                         value_serializer=lambda x: json.dumps(x).encode('utf-8'))


    # Poll for messages
    try:
        for message in consumer:
            try:
                data = message.value
                # Customer
                storNumber = int(data.get('StoreNumber', ''))
                if not storNumber:
                    logger.error("StoreNumber is null or invalid. Skipping insertion.")
                    pass

                storeName = data.get('StoreName', '')
                address = data.get('Address', '')
                city = data.get('City', '')
                county = data.get('County', '')
                state = data.get('State', '')
                zip_code = int(data.get('ZipCode', ''))

                # vendor
                vendorNumber = int(float(data.get('VendorNumber', '')))
                if not vendorNumber:
                    logger.error("VendorNumber is null or invalid. Skipping insertion.")
                    pass

                vendorName = data.get('VendorName', '')

                # category
                category = int(float(data.get('Category','')))
                if not category:
                    logger.error("Category is null or invalid. Skipping insertion.")
                    pass

                categoryName = (data.get('CategoryName',''))

                # product
                itemNumber = int(data.get('ItemNumber', ''))
                if not itemNumber:
                    logger.error("ItemNumber is null or invalid. Skipping insertion.")
                    pass
                itemDescription = data.get('ItemDescription', '')
                pack = int(data.get('Pack', ''))
                volume = int(data.get('BottleVolumeML', ''))
                cost = float(data.get('BottleCost', '').replace('$', ''))
                retail = float(data.get('BottleRetail', '').replace('$', ''))

                # Sales
                invoice = data.get('Invoice', '')
                if not invoice:
                    logger.error("Invoice is null or invalid. Skipping insertion.")
                    pass

                date_str = data.get('Date', '')
                if not date_str:
                    logger.error("Date is null or invalid. Skipping insertion.")
                    pass

                sales_date = datetime.datetime.strptime(date_str, '%m/%d/%Y').date()

                amountSold = int(data.get('BottlesSold', ''))
                totalLiters = float(data.get('VolumeSoldLiters', ''))

                sales_str = data.get('SaleDollars', '').replace('$', '')
                sales = float(sales_str)

                # MySQL
                '''
                Multiple try/except blocks are used due to the simplistic invoicing
                application script.

                In a real world scenario, likely each of these blocks would be done
                as a truly separate process.

                The try/except prevents the duplicates failing to be added to the
                database from preventing the rest of the processes from competing.
                '''

                print('customer')
                try:
                    CUSTOMER_QUERY = '''
                        INSERT INTO customer (StoreNumber,StoreName,Address,City,CountyName,State,ZipCode)
                        VALUES (%s,%s,%s,%s,%s,%s,%s)
                        '''
                    customer_data = (storNumber,storeName,address,city,county,state,zip_code)
                    mysql_cursor.execute(CUSTOMER_QUERY, customer_data)
                    mysql_conn.commit()
                except Exception as e:
                    pass

                print('vendor')
                try:
                    VENDOR_QUERY = '''
                        INSERT INTO vendor (VendorNumber,VendorName)
                        VALUES (%s,%s)
                        '''
                    vendor_data = (vendorNumber,vendorName)
                    mysql_cursor.execute(VENDOR_QUERY,vendor_data)
                    mysql_conn.commit()
                except Exception as e:
                    pass

                print(category)
                try:
                    CATEGORY_QUERY = '''
                        INSERT INTO category (CategoryNumber,CategoryName)
                        VALUES (%s,%s)
                        '''
                    category_data = (category,categoryName)
                    mysql_cursor.execute(CATEGORY_QUERY, category_data)
                    mysql_conn.commit()
                except Exception as e:
                    logger.error("StoreNumber is null or invalid. Skipping insertion.")
                    pass

                print('product')
                try:
                    PRODUCT_QUERY = '''
                        INSERT INTO product (ItemNumber,CategoryNumber,ItemDescription,BottleVolumeML,
                        Pack,BottleCost,BottleRetail)
                        VALUES (%s,%s,%s,%s,%s,%s,%s)
                        '''
                    product_data = (itemNumber,category,itemDescription,volume,pack,cost,retail)
                    mysql_cursor.execute(PRODUCT_QUERY, product_data)
                    mysql_conn.commit()
                except Exception as e:
                    logger.error("StoreNumber is null or invalid. Skipping insertion.")
                    pass

                print(sales)
                try:
                    SALES_QUERY = '''
                    INSERT INTO sales (Invoice,StoreNumber,VendorNumber,SaleDate,SaleDollars,
                    ItemNumber,VolumeSoldLiters,BottlesSold)
                    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
                    '''
                    sales_data = (invoice,storNumber,vendorNumber,sales_date,sales,itemNumber,
                                    totalLiters,amountSold)
                    mysql_cursor.execute(SALES_QUERY, sales_data)
                    mysql_conn.commit()
                except Exception as e:
                    logger.error("StoreNumber is null or invalid. Skipping insertion.")
                    pass

                print('topic')
                # Topic should post after MySQL processing to ensure data is in the database.
                try:
                    sales_date_str = str(sales_date)
                    INVOICES_info = {
                        "Invoice": invoice,
                        "SaleDate": sales_date_str,
                        "saleDollars": sales_str
                    }

                    invoice_producer.send('invoices', value=INVOICES_info)
                    invoice_producer.flush()
                except Exception as e:
                    logger.error("StoreNumber is null or invalid. Skipping insertion.", exc_info=True)
                    pass

            except Exception as e:
                print(f"Error in Kafka consumer: {e}", exc_info=True)
                pass

    # Close the consumer
    finally:
        consumer.close()
        mysql_conn.close()

# %%
mysql_consumer()
# Out:
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '238' for key 'product.PRIMARY'
# 104.58
# Error processing message: 1062 (23000): Duplicate entry 'S28865700001' for key 'sales.PRIMARY'
# topic
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '173' for key 'product.PRIMARY'
# 117.48
# topic
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '238' for key 'product.PRIMARY'
# 17.43
# topic
# customer
# vendor
# 1081200
# Error processing message: 1062 (23000): Duplicate entry '1081200' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '258' for key 'product.PRIMARY'
# 148.5
# Error processing message: 1062 (23000): Duplicate entry 'S29134300126' for key 'sales.PRIMARY'
# topic
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '238' for key 'product.PRIMARY'
# 104.58
# topic
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '238' for key 'product.PRIMARY'
# 52.29
# topic
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '238' for key 'product.PRIMARY'
# 104.58
# topic
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '238' for key 'product.PRIMARY'
# 34.86
# Error processing message: 1062 (23000): Duplicate entry 'S28867100001' for key 'sales.PRIMARY'
# topic
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '173' for key 'product.PRIMARY'
# 1057.32
# Error processing message: 1062 (23000): Duplicate entry 'S29191200001' for key 'sales.PRIMARY'
# topic
# customer
# vendor
# 1701100
# Error processing message: 1062 (23000): Duplicate entry '1701100' for key 'category.PRIMARY'
# product
# Error processing message: 1062 (23000): Duplicate entry '238' for key 'product.PRIMARY'
# 209.16
# Error processing message: 1062 (23000): Duplicate entry 'S29137200001' for key 'sales.PRIMARY'
# topic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mysql_consumer()
#
# Cell In[10], line 27, in mysql_consumer()
#      25 # Poll for messages
#      26 try:
# ---> 27     for message in consumer:
#      28         try:
#      29             data = message.value
#
# File ~/miniconda3/envs/kafka2/lib/python3.11/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/miniconda3/envs/kafka2/lib/python3.11/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/miniconda3/envs/kafka2/lib/python3.11/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/miniconda3/envs/kafka2/lib/python3.11/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/miniconda3/envs/kafka2/lib/python3.11/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/miniconda3/envs/kafka2/lib/python3.11/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/miniconda3/envs/kafka2/lib/python3.11/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/miniconda3/envs/kafka2/lib/python3.11/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
import pandas as pd

df = pd.read_csv("data/Iowa_Liquor_Sales.csv", nrows=10)

print(df)

# %%
print(df.columns)

# %%
# sample output
'''
{'Invoice/Item Number': 'S29198800001', 'Date': '11/20/2015', 'Store Number': '2191', 'Store Name': 'Keokuk Spirits', 
'Address': '1013 MAIN', 'City': 'KEOKUK', 'Zip Code': '52632', 'Store Location': '1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)', 
'County Number': '56', 'County': 'Lee', 'Category': '', 'Category Name': '', 'Vendor Number': '255', 'Vendor Name': 'Wilson Daniels Ltd.', 
'Item Number': '297', 'Item Description': 'Templeton Rye w/Flask', 'Pack': '6', 'Bottle Volume (ml)': '750', 'State Bottle Cost': '$18.09', 
'State Bottle Retail': '$27.14', 'Bottles Sold': '6', 'Sale (Dollars)': '$162.84', 'Volume Sold (Liters)': '4.50', 'Volume Sold (Gallons)': '1.19'}
'''

# %%
with open("../data/Iowa_Liquor_Sales.csv", 'r') as file:
    reader = csv.DictReader(file)
    while True:
        chunk = []
        for _ in range(1000):
            try:
                chunk.append(next(reader))
            except StopIteration:
                break
        if not chunk:
            break
        for row in chunk:
            print(row)

# %%
# money conversion test
data = {'SaleDollars': '$12.34'}

sales = float(data.get('SaleDollars','').replace('$', ''))

sales

# %%
# datetime test
from datetime import datetime

date_data = {"Date":"11/09/2015"}

date_string = date_data.get('Date', '')
invoice_date = datetime.strptime(date_string,'%m/%d/%Y').date()

print(invoice_date)
